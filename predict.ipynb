# %%
import pickle

# %%
with open("model.pkl", "rb") as f:
    model = pickle.load(f)

# %%
x_new = [[10]]

# %%
with open("scalar.pkl", "rb") as f:
    scalar = pickle.load(f)

# %%
x_new_scaled = scalar.transform(x_new)
# Out:
# /home/saumya/anaconda3/envs/machinelearning/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
prediction = model.predict(x_new_scaled)

# %%
print(prediction)
# Out:
# [95.59754955]
